# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
df = pd.read_csv('RUNS.csv')

# %%
df.head(10)
# Out:
#    etape    MAgP  P[0.1]               Nom
# 0      1   0.690    2.77               btc
# 1      2   2.100    5.34               ltc
# 2      5  23.240   52.24       bm25_b_0.50
# 3      5  24.000   50.16      tfidfepsilon
# 4      5   2.320    7.49               ntn
# 5      5  16.460   35.39               lsn
# 6      5  20.670   49.34               ltn
# 7      9   0.211    0.65  bm25_page_rank_1

# %%
sns.distplot(df['P[0.1]'])
# Out:
# c:\program files\python36\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='P[0.1]', ylabel='Density'>

# %%
sns.distplot(df['MAgP'])
# Out:
# c:\program files\python36\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='MAgP', ylabel='Density'>

# %%
plt.figure(figsize=(12, 8))
sns.distplot(df['P[0.1]'])
# Out:
# c:\program files\python36\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='P[0.1]', ylabel='Density'>

# %%
plt.figure(figsize=(12, 8))
sns.distplot(df['MAgP'])
# Out:
# c:\program files\python36\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='MAgP', ylabel='Density'>

# %%
sns.countplot(x='P[0.1]',data=df)
# Out:
# <AxesSubplot:xlabel='P[0.1]', ylabel='count'>

# %%
sns.countplot(x='MAgP',data=df)
# Out:
# <AxesSubplot:xlabel='MAgP', ylabel='count'>

# %%
sns.countplot(x='etape',data=df,hue='P[0.1]')
# Out:
# <AxesSubplot:xlabel='etape', ylabel='count'>

# %%
sns.countplot(x='etape',data=df,hue='MAgP')
# Out:
# <AxesSubplot:xlabel='etape', ylabel='count'>

# %%
sns.countplot(x='MAgP',data=df,hue='P[0.1]')
# Out:
# <AxesSubplot:xlabel='MAgP', ylabel='count'>

# %%
sns.countplot(x='MAgP',data=df,palette='terrain')
# Out:
# <AxesSubplot:xlabel='MAgP', ylabel='count'>

# %%
sns.countplot(x='P[0.1]',data=df,palette='terrain',hue= 'MAgP')
# Out:
# <AxesSubplot:xlabel='P[0.1]', ylabel='count'>

# %%
sns.countplot(x='MAgP',data=df,palette='terrain',hue= 'P[0.1]')
# Out:
# <AxesSubplot:xlabel='MAgP', ylabel='count'>

# %%
plt.barh(df['Nom'],df['MAgP'],align='center') # A bar chart
#plt.xlabel('percentage')
plt.ylabel('MAgP')

#for i in range(len(y)):
#    plt.hlines(y[i],0,x[i]) # Here you are drawing the horizontal lines
fig0 = plt.gcf()
plt.show()
plt.draw()
fig0.savefig("MAgp.png", dpi=100)

# %%
plt.barh(df['Nom'],df['P[0.1]'],align='center') # A bar chart
#plt.xlabel('percentage')
plt.ylabel('P[0.1]')
#for i in range(len(y)):
#    plt.hlines(y[i],0,x[i]) # Here you are drawing the horizontal lines
fig1 = plt.gcf()
plt.show()
plt.draw()
fig1.savefig("precision.png", dpi=100)
